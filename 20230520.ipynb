# %% [markdown]
# # Set up environment

# %%
# Install YOLOv5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-169-g3250272 Python-3.11.3 torch-2.0.1 CPU
# Setup complete ✅ (12 CPUs, 16.0 GB RAM, 145.5/223.5 GB disk)

# %% [markdown]
# # Detect objects in a video

# %%
# Edit the path to the source file below
source = '~/Downloads/Videos_Raw/MF_StreetView.MOV'

# %%
# !python detect.py --weights ./last.pt --source {source}
# Out:
# detect: weights=['./last.pt'], source=/Users/hokinlok/Downloads/Videos_Raw/MF_StreetView.MOV, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: /Users/hokinlok/.pyenv/versions/3.11.3/lib/python3.11/site-packages/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-169-g3250272 Python-3.11.3 torch-2.0.1 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7037095 parameters, 0 gradients
# video 1/1 (1/5659) /Users/hokinlok/Downloads/Videos_Raw/MF_StreetView.MOV: 384x640 1 look left, 1 look right, 1 tactile guide path, 217.5ms
# ...
